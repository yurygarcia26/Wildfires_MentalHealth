# %%
# !pip install optuna

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords, wordnet
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import WordNetLemmatizer
import os
import string
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
from sklearn.manifold import TSNE
import itertools
import collections
from collections import Counter
from gensim import corpora, models
from gensim.models import Word2Vec, word2vec, LdaModel
import optuna
from hyperopt import hp, tpe, fmin
import warnings
warnings.filterwarnings("ignore")
import gensim
from gensim.utils import simple_preprocess
from datetime import datetime
# import spacy
from nltk import pos_tag
import pickle

# %%
nltk.download('averaged_perceptron_tagger')
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls 'drive/MyDrive/5.TopicModeling/Data'

# %%
df = pd.read_csv('drive/MyDrive/5.TopicModeling/Data/final_tubbs.csv', encoding='latin-1')
df['tweet_created_at'] = pd.to_datetime(df["tweet_created_at"])
df['tweet_created_at'] = df['tweet_created_at'].dt.strftime('%Y-%m-%d')
df

# %% [markdown]
# ### separating data into three difference period
#
# 09/02/2017-10/07/2017: Before wildfire
#
# 10/08/2017-10/31/2017: During wildfire
#
# 11/01/2017-12/01/2017: After wildfire

# %%
#before wildfire
start_date = '2017-10-08'
end_date = '2017-10-31'

filtered_df = df[(df['tweet_created_at'] >= start_date) & (df['tweet_created_at'] <= end_date)]
filtered_df

# %% [markdown]
# # Word Distribution

# %%
wordcounter = Counter()
# Update the Counter with all tokens in the 'lemm_text' column
for tokens in filtered_df['lemm_text']:
    wordcounter.update(tokens)
filtered_df['lemm_textA'] = [[word for word in tokens if wordcounter[word] >= 100] for tokens in filtered_df['lemm_text']]
filtered_df

# %% [markdown]
# # Find dimension

# %%
# Create an instance of CountVectorizer
vectorizer = CountVectorizer(
                             max_features = 1000)

# document_texts = [' '.join(tokens) for tokens in df['lemm_text']]
document_texts = [tokens for tokens in filtered_df['lemm_text']]


# Fit the vectorizer on the 'lemm_text' column
vectorizer.fit(document_texts)

# Transform the 'lemm_text' column into a count vector representation
count_vector = vectorizer.transform(document_texts)

# Get the dimensions of the count vector
vector_dimensions = count_vector.shape

# Print the dimensions
print("Count Vector Dimensions:", vector_dimensions)
# Out:
# Count Vector Dimensions: (81423, 1000)

# %% [markdown]
# # SK LDA

# %%
# #try from 10 to 100 topics iterations
# X = count_vector

# topic_range = range(10,101,10)
# perplexities = []

# for i in topic_range:
#   ldask = LatentDirichletAllocation(n_components = i, random_state = 5566)
#   ldask.fit(X)
#   perplexity = ldask.perplexity(X)
#   perplexities.append(perplexity)
#   print("Number of topics: {}, Perplexity: {}".format(i, perplexity))

# %%
# # Print the top words for each topic

# ldask30 = LatentDirichletAllocation(n_components = 30, random_state = 5566)
# ldask30.fit(X)

# feature_names = vectorizer.get_feature_names_out()
# for topic_idx, topic in enumerate(ldask30.components_):
#     print(f"Topic #{topic_idx + 1}:")
#     top_words_idx = topic.argsort()[:-16:-1]  # Select top 15 words
#     top_words = [feature_names[i] for i in top_words_idx]
#     print(top_words)
#     print()

# %%
# save model
# Save the LDA model
# with open('drive/MyDrive/5.TopicModeling/Model/lda_during_wildfire_sk', 'wb') as file:
#     pickle.dump(ldask30, file)

# %%
# # Load the LDA model
# model_path = 'drive/MyDrive/5.TopicModeling/Model/lda_during_wildfire_sk'
# with open(model_path, 'rb') as file:
#     lda_dw_sk = pickle.load(file)

# for topic_idx, topic in enumerate(lda_dw_sk.components_):
#     print(f"Topic #{topic_idx + 1}:")
#     top_words_idx = topic.argsort()[:-16:-1]  # Select top 15 words
#     top_words = [feature_names[i] for i in top_words_idx]
#     print(top_words)
#     print()

# %%
# # Define the objective function for optimization
# def objective(trial):
#     n_topics = trial.suggest_int('n_topics', 10, 100)
#     alpha = trial.suggest_uniform('alpha', 0.1, 1.0)
#     beta = trial.suggest_uniform('beta', 0.1, 1.0)

#     lda = LatentDirichletAllocation(
#         n_components=n_topics,
#         doc_topic_prior=alpha,
#         topic_word_prior=beta,
#         random_state=42
#     )

#     lda.fit(X)
#     perplexity = lda.perplexity(X)
#     return perplexity

# # Run the optimization
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=50)

# # Print the best hyperparameters and objective value
# best_params = study.best_params
# best_value = study.best_value
# print("Best Hyperparameters: ", best_params)
# print("Best Objective Value: ", best_value)

# %%
# # Print the top words for each topic

# ldask_mod = LatentDirichletAllocation(n_components = 12, random_state = 5566,
#                                     doc_topic_prior = 0.10032827992479586, topic_word_prior = 0.10511489014645924)
# ldask_mod.fit(X)

# feature_names = vectorizer.get_feature_names_out()
# for topic_idx, topic in enumerate(ldask_mod.components_):
#     print(f"Topic #{topic_idx + 1}:")
#     top_words_idx = topic.argsort()[:-16:-1]  # Select top 15 words
#     top_words = [feature_names[i] for i in top_words_idx]
#     print(top_words)
#     print()

# %% [markdown]
# # Gensim LDA

# %%
# Create a list of lists from the preprocessed documents
# processed_docs = [doc.split() for doc in df['lemm_text']]
processed_docs = [re.sub(r'[\[\],]', '', doc).split() for doc in filtered_df['lemm_text']]
dictionary = corpora.Dictionary(processed_docs)
# dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=1000)  # Limit the dictionary size
# Convert the dictionary into a bag-of-words representation
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# Initialize the LDA model with 10 top
num_topics = 10
lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, random_state = 5566)

# %%
# Increase the number of topics from 10 to 100
new_num_topics = 100

while num_topics < new_num_topics:
    # Increase the number of topics
    num_topics += 10

    # Re-train the LDA model with the updated number of topics
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary)

    # Evaluate the model's performance (using coherence score as an example)
    coherence_score = models.CoherenceModel(model=lda_model, texts=processed_docs, dictionary=dictionary, coherence='c_v').get_coherence()

    print(f"Number of topics: {num_topics}, Coherence Score: {coherence_score}")

    # Repeat the process until the desired number of topics or satisfactory results are achieved
# Out:
# Number of topics: 20, Coherence Score: 0.3257249003340329
# Number of topics: 30, Coherence Score: 0.33566066046059245
# Number of topics: 40, Coherence Score: 0.3625941371363871
# Number of topics: 50, Coherence Score: 0.39226988064641616
# Number of topics: 60, Coherence Score: 0.4330458655316968
# Number of topics: 70, Coherence Score: 0.4297123292204261
# Number of topics: 80, Coherence Score: 0.41786233854256005
# Number of topics: 90, Coherence Score: 0.3812857901127664
# Number of topics: 100, Coherence Score: 0.3563034649886238

# %%
#try new topic model
lda_modelA = models.LdaModel(corpus, num_topics=60, id2word=dictionary)
for i,topic in lda_modelA.show_topics(formatted=True, num_topics=60, num_words=15):
    print(str(i)+": "+ topic)
    print()

# %% [markdown]
# #Parameter Modification (Optuna)

# %%
def objective(trial):
    num_topics = trial.suggest_int('num_topics', 10, 100)
    # iterations = trial.suggest_int('iterations', 50, 100)
    alpha = trial.suggest_categorical('alpha', ['symmetric', 'asymmetric'])
    eta = trial.suggest_float('eta', 0.1, 1.0)
    # rounded_eta = round(suggested_eta, 2)

    # Handle None values for hyperparameters
    # alpha = 1.0 if alpha is None else alpha
    # beta = 1.0 if beta is None else beta

    # Train the LDA model with the current hyperparameters
    lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics,
                         alpha=alpha, eta=eta)

    # Calculate coherence score for the model
    coherence_model = models.CoherenceModel(model=lda_model, texts=processed_docs, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    return coherence_score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Print the best hyperparameters and coherence score
best_params = study.best_params
best_coherence = study.best_value
print("Best number of topics:", best_params['num_topics'])
print("Best alpha:", best_params['alpha'])
print("Best beta:", best_params['eta'])
print("Best coherence score:", best_coherence)
# Out:
# [I 2023-06-29 04:58:57,061] A new study created in memory with name: no-name-e973a303-5215-40ee-8dff-8d1b0eb395fb
# [I 2023-06-29 04:59:52,794] Trial 0 finished with value: 0.41172230954855166 and parameters: {'num_topics': 78, 'alpha': 'symmetric', 'eta': 0.7769296655706582}. Best is trial 0 with value: 0.41172230954855166.
# [I 2023-06-29 05:00:36,615] Trial 1 finished with value: 0.40370986842432655 and parameters: {'num_topics': 69, 'alpha': 'symmetric', 'eta': 0.8535866220164786}. Best is trial 0 with value: 0.41172230954855166.
# [I 2023-06-29 05:01:14,788] Trial 2 finished with value: 0.4492364898852266 and parameters: {'num_topics': 48, 'alpha': 'symmetric', 'eta': 0.6690895760570656}. Best is trial 2 with value: 0.4492364898852266.
# [I 2023-06-29 05:02:02,646] Trial 3 finished with value: 0.49219966753514904 and parameters: {'num_topics': 77, 'alpha': 'asymmetric', 'eta': 0.22976721446366735}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:02:33,351] Trial 4 finished with value: 0.37176689068894475 and parameters: {'num_topics': 19, 'alpha': 'asymmetric', 'eta': 0.32800274350683156}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:03:35,729] Trial 5 finished with value: 0.4311581841528617 and parameters: {'num_topics': 100, 'alpha': 'symmetric', 'eta': 0.5420366435890952}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:04:25,777] Trial 6 finished with value: 0.4125978750127758 and parameters: {'num_topics': 85, 'alpha': 'asymmetric', 'eta': 0.6484911924730479}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:05:07,546] Trial 7 finished with value: 0.4503684008847906 and parameters: {'num_topics': 54, 'alpha': 'symmetric', 'eta': 0.6688337739639606}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:05:56,407] Trial 8 finished with value: 0.39803245776795304 and parameters: {'num_topics': 78, 'alpha': 'asymmetric', 'eta': 0.7191345600076572}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:06:30,435] Trial 9 finished with value: 0.45931660423883885 and parameters: {'num_topics': 26, 'alpha': 'asymmetric', 'eta': 0.6208772224999694}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:07:02,139] Trial 10 finished with value: 0.3690762030089364 and parameters: {'num_topics': 33, 'alpha': 'asymmetric', 'eta': 0.14668750537338388}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:07:36,756] Trial 11 finished with value: 0.4575333658415642 and parameters: {'num_topics': 36, 'alpha': 'asymmetric', 'eta': 0.9846151094189566}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:08:08,321] Trial 12 finished with value: 0.38542986095227594 and parameters: {'num_topics': 14, 'alpha': 'asymmetric', 'eta': 0.4651198815950004}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:08:53,477] Trial 13 finished with value: 0.4664147611063798 and parameters: {'num_topics': 64, 'alpha': 'asymmetric', 'eta': 0.40129506806875814}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:09:37,934] Trial 14 finished with value: 0.47363106360768936 and parameters: {'num_topics': 64, 'alpha': 'asymmetric', 'eta': 0.3272600774239249}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:10:29,764] Trial 15 finished with value: 0.4892296828101525 and parameters: {'num_topics': 91, 'alpha': 'asymmetric', 'eta': 0.2456899367118708}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:11:19,909] Trial 16 finished with value: 0.4644127450460133 and parameters: {'num_topics': 95, 'alpha': 'asymmetric', 'eta': 0.10992659985655487}. Best is trial 3 with value: 0.49219966753514904.
# [I 2023-06-29 05:12:12,483] Trial 17 finished with value: 0.49776116780405916 and parameters: {'num_topics': 90, 'alpha': 'asymmetric', 'eta': 0.19107272688574609}. Best is trial 17 with value: 0.49776116780405916.
# [I 2023-06-29 05:12:59,278] Trial 18 finished with value: 0.48056189412456035 and parameters: {'num_topics': 81, 'alpha': 'asymmetric', 'eta': 0.21053419242837162}. Best is trial 17 with value: 0.49776116780405916.
# [I 2023-06-29 05:13:42,893] Trial 19 finished with value: 0.46768039399575506 and parameters: {'num_topics': 72, 'alpha': 'asymmetric', 'eta': 0.10772343060386945}. Best is trial 17 with value: 0.49776116780405916.
# [I 2023-06-29 05:14:45,828] Trial 20 finished with value: 0.506675084021305 and parameters: {'num_topics': 88, 'alpha': 'asymmetric', 'eta': 0.23525127417199476}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:15:35,544] Trial 21 finished with value: 0.5001875228806774 and parameters: {'num_topics': 87, 'alpha': 'asymmetric', 'eta': 0.23065705871180436}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:16:29,198] Trial 22 finished with value: 0.49634022941301353 and parameters: {'num_topics': 89, 'alpha': 'asymmetric', 'eta': 0.304135008908246}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:17:25,062] Trial 23 finished with value: 0.48768995395384884 and parameters: {'num_topics': 100, 'alpha': 'asymmetric', 'eta': 0.18673477118599352}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:18:16,439] Trial 24 finished with value: 0.4879653037422005 and parameters: {'num_topics': 87, 'alpha': 'asymmetric', 'eta': 0.2707145850835845}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:19:06,070] Trial 25 finished with value: 0.47715443539282854 and parameters: {'num_topics': 96, 'alpha': 'asymmetric', 'eta': 0.1700983341301304}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:19:46,086] Trial 26 finished with value: 0.47293066404449646 and parameters: {'num_topics': 59, 'alpha': 'symmetric', 'eta': 0.376452392873244}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:20:37,175] Trial 27 finished with value: 0.489624921933805 and parameters: {'num_topics': 86, 'alpha': 'asymmetric', 'eta': 0.24413624779942744}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:21:19,968] Trial 28 finished with value: 0.47318074713992536 and parameters: {'num_topics': 69, 'alpha': 'asymmetric', 'eta': 0.18096810828634738}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:22:10,391] Trial 29 finished with value: 0.4688889839882922 and parameters: {'num_topics': 75, 'alpha': 'symmetric', 'eta': 0.3799087516349723}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:22:50,012] Trial 30 finished with value: 0.4793661692139338 and parameters: {'num_topics': 46, 'alpha': 'asymmetric', 'eta': 0.27372438406172495}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:23:57,788] Trial 31 finished with value: 0.4810395144213477 and parameters: {'num_topics': 91, 'alpha': 'asymmetric', 'eta': 0.30570017998617033}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:24:47,030] Trial 32 finished with value: 0.48779822304460824 and parameters: {'num_topics': 82, 'alpha': 'asymmetric', 'eta': 0.15464012815926806}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:25:41,563] Trial 33 finished with value: 0.494409427236277 and parameters: {'num_topics': 89, 'alpha': 'asymmetric', 'eta': 0.21363942032357813}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:26:43,504] Trial 34 finished with value: 0.4906340310265491 and parameters: {'num_topics': 96, 'alpha': 'symmetric', 'eta': 0.3015804872863962}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:27:33,932] Trial 35 finished with value: 0.4890718947168332 and parameters: {'num_topics': 81, 'alpha': 'asymmetric', 'eta': 0.23650955111365995}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:28:23,568] Trial 36 finished with value: 0.45192877011911115 and parameters: {'num_topics': 92, 'alpha': 'asymmetric', 'eta': 0.10171753941876396}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:29:20,278] Trial 37 finished with value: 0.48650205302278815 and parameters: {'num_topics': 75, 'alpha': 'symmetric', 'eta': 0.29939635395596004}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:30:06,489] Trial 38 finished with value: 0.5011950091189848 and parameters: {'num_topics': 69, 'alpha': 'asymmetric', 'eta': 0.3538609599332103}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:30:53,937] Trial 39 finished with value: 0.4981253402248118 and parameters: {'num_topics': 67, 'alpha': 'asymmetric', 'eta': 0.4508235924797674}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:31:34,674] Trial 40 finished with value: 0.4627609225418428 and parameters: {'num_topics': 52, 'alpha': 'symmetric', 'eta': 0.4976751494923384}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:32:23,864] Trial 41 finished with value: 0.48608284052567263 and parameters: {'num_topics': 63, 'alpha': 'asymmetric', 'eta': 0.36733665639746393}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:33:13,917] Trial 42 finished with value: 0.4762109821283692 and parameters: {'num_topics': 70, 'alpha': 'asymmetric', 'eta': 0.40704752131020183}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:34:05,744] Trial 43 finished with value: 0.46100927907469785 and parameters: {'num_topics': 78, 'alpha': 'asymmetric', 'eta': 0.4455568883569281}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:34:59,162] Trial 44 finished with value: 0.47824383124223174 and parameters: {'num_topics': 83, 'alpha': 'asymmetric', 'eta': 0.3508371505576759}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:35:47,040] Trial 45 finished with value: 0.4708683940890854 and parameters: {'num_topics': 69, 'alpha': 'asymmetric', 'eta': 0.3460684388950579}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:36:31,175] Trial 46 finished with value: 0.4809790057010546 and parameters: {'num_topics': 58, 'alpha': 'asymmetric', 'eta': 0.5329718272043865}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:37:29,448] Trial 47 finished with value: 0.4437604507495491 and parameters: {'num_topics': 100, 'alpha': 'asymmetric', 'eta': 0.4219088171856303}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:38:09,733] Trial 48 finished with value: 0.45894936605045794 and parameters: {'num_topics': 45, 'alpha': 'asymmetric', 'eta': 0.2580274366361984}. Best is trial 20 with value: 0.506675084021305.
# [I 2023-06-29 05:39:01,424] Trial 49 finished with value: 0.4606169582489658 and parameters: {'num_topics': 65, 'alpha': 'asymmetric', 'eta': 0.5999568771326256}. Best is trial 20 with value: 0.506675084021305.
# Best number of topics: 88
# Best alpha: asymmetric
# Best beta: 0.23525127417199476
# Best coherence score: 0.506675084021305

# %%
modified_lda_model = LdaModel(corpus, id2word = dictionary,
                       num_topics = best_params['num_topics'], alpha = best_params['alpha'],
                       eta = best_params['eta'])
for i,topic in modified_lda_model.show_topics(formatted=True, num_topics=best_params['num_topics'], num_words=15):
    print(str(i)+": "+ topic)
    print()

# Best number of topics: 88
# Best alpha: asymmetric
# Best beta: 0.23525127417199476
# Best coherence score: 0.506675084021305

# %%
# save model
# with open('drive/MyDrive/5.TopicModeling/Model/lda_duringWildfire_mod', 'wb') as file:
#     pickle.dump(modified_lda_model, file)

# %%
# Load the LDA model
model_path = 'drive/MyDrive/5.TopicModeling/Model/lda_duringWildfire_mod'
with open(model_path, 'rb') as file:
    modified_lda_model = pickle.load(file)

topics = []
#implement model
for i,topic in modified_lda_model.show_topics(formatted=True, num_topics=88, num_words=15):
    topics.append(topic)
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.128*"'fire'" + 0.116*"'angry'" + 0.090*"'say'" + 0.036*"'california'" + 0.034*"'smoke'" + 0.027*"'high'" + 0.021*"'wildfire'" + 0.020*"'long'" + 0.018*"'deadly'" + 0.017*"'close'" + 0.014*"'school'" + 0.014*"'pay'" + 0.011*"'pot'" + 0.010*"'chicago'" + 0.010*"'room'"
#
# 1: 0.427*"'smoke'" + 0.059*"'day'" + 0.045*"'weed'" + 0.024*"'cigarette'" + 0.016*"'bore'" + 0.015*"'depression'" + 0.014*"'hand'" + 0.013*"'fall'" + 0.013*"'second'" + 0.012*"'part'" + 0.010*"'washington'" + 0.007*"'wildfire'" + 0.007*"'mad'" + 0.007*"'fire'" + 0.006*"'ravage'"
#
# 2: 0.206*"'get'" + 0.130*"'fire'" + 0.060*"'know'" + 0.032*"'dumpster'" + 0.027*"'tired'" + 0.024*"'ever'" + 0.018*"'liar'" + 0.012*"'money'" + 0.012*"'hour'" + 0.009*"'sex'" + 0.008*"'burn'" + 0.008*"'map'" + 0.007*"'nervous'" + 0.007*"'chill'" + 0.007*"'less'"
#
# 3: 0.285*"'sad'" + 0.181*"'fire'" + 0.092*"'tire'" + 0.032*"'still'" + 0.029*"'good'" + 0.026*"'work'" + 0.024*"'hear'" + 0.015*"'amp'" + 0.012*"'california'" + 0.011*"'turn'" + 0.010*"'happy'" + 0.010*"'tweet'" + 0.010*"'relief'" + 0.007*"'crazy'" + 0.007*"'omg'"
#
# 4: 0.121*"'fire'" + 0.063*"'california'" + 0.059*"'least'" + 0.054*"'dead'" + 0.052*"'thing'" + 0.052*"'news'" + 0.044*"'lol'" + 0.041*"'contain'" + 0.023*"'destroy'" + 0.021*"'friday'" + 0.020*"'late'" + 0.018*"'music'" + 0.015*"'wildfire'" + 0.011*"'tomorrow'" + 0.010*"'home'"
#
# 5: 0.089*"'fire'" + 0.073*"'right'" + 0.054*"'pure'" + 0.039*"'state'" + 0.026*"'devastate'" + 0.025*"'maybe'" + 0.025*"'california'" + 0.018*"'stand'" + 0.018*"'history'" + 0.016*"'thanks'" + 0.015*"'become'" + 0.014*"'large'" + 0.014*"'park'" + 0.012*"'ice'" + 0.012*"'rather'"
#
# 6: 0.117*"'new'" + 0.102*"'struggle'" + 0.062*"'gon'" + 0.031*"'add'" + 0.029*"'spooky'" + 0.026*"'crop'" + 0.020*"'control'" + 0.017*"'cool'" + 0.014*"'wildfire'" + 0.012*"'california'" + 0.011*"'door'" + 0.011*"'album'" + 0.010*"'create'" + 0.009*"'gif'" + 0.009*"'playlist'"
#
# 7: 0.096*"'dont'" + 0.037*"'prayer'" + 0.031*"'thought'" + 0.027*"'affect'" + 0.027*"'fire'" + 0.023*"'resident'" + 0.020*"'destruction'" + 0.018*"'huge'" + 0.013*"'spit'" + 0.011*"'test'" + 0.011*"'spoiler'" + 0.009*"'central'" + 0.008*"'complete'" + 0.008*"'art'" + 0.008*"'around'"
#
# 8: 0.053*"'woman'" + 0.045*"'seem'" + 0.035*"'fire'" + 0.032*"'beat'" + 0.024*"'touch'" + 0.018*"'weather'" + 0.015*"'suffer'" + 0.015*"'hero'" + 0.015*"'rip'" + 0.015*"'neighborhood'" + 0.014*"'parent'" + 0.013*"'easy'" + 0.012*"'camp'" + 0.012*"'awful'" + 0.011*"'special'"
#
# 9: 0.102*"'back'" + 0.092*"'devastation'" + 0.049*"'wait'" + 0.045*"'police'" + 0.036*"'bring'" + 0.028*"'fire'" + 0.026*"'wake'" + 0.019*"'threatens'" + 0.013*"'protect'" + 0.012*"'order'" + 0.010*"'block'" + 0.010*"'suspect'" + 0.009*"'reality'" + 0.007*"'friends'" + 0.007*"'bos'"
#
# 10: 0.111*"'santa'" + 0.104*"'fire'" + 0.101*"'rosa'" + 0.039*"'place'" + 0.038*"'baby'" + 0.015*"'energy'" + 0.011*"'industry'" + 0.011*"'doctor'" + 0.010*"'calif'" + 0.010*"'tubbs'" + 0.009*"'recover'" + 0.007*"'store'" + 0.007*"'displace'" + 0.006*"'burn'" + 0.006*"'exit'"
#
# 11: 0.043*"'continue'" + 0.032*"'sky'" + 0.031*"'tough'" + 0.028*"'wildfires'" + 0.022*"'survive'" + 0.021*"'dark'" + 0.018*"'fill'" + 0.017*"'fire'" + 0.015*"'apartment'" + 0.015*"'rethink'" + 0.014*"'california'" + 0.012*"'rage'" + 0.012*"'wall'" + 0.012*"'involve'" + 0.010*"'student'"
#
# 12: 0.159*"'make'" + 0.136*"'fire'" + 0.082*"'really'" + 0.032*"'safety'" + 0.028*"'lake'" + 0.024*"'anything'" + 0.016*"'upgrade'" + 0.015*"'boo'" + 0.015*"'funny'" + 0.015*"'ready'" + 0.014*"'drive'" + 0.012*"'nervous'" + 0.012*"'east'" + 0.011*"'sorry'" + 0.010*"'issue'"
#
# 13: 0.089*"'set'" + 0.073*"'fire'" + 0.056*"'well'" + 0.052*"'game'" + 0.047*"'burn'" + 0.040*"'way'" + 0.038*"'coach'" + 0.034*"'old'" + 0.030*"'girl'" + 0.020*"'read'" + 0.018*"'wildfire'" + 0.017*"'president'" + 0.016*"'california'" + 0.014*"'kinda'" + 0.014*"'lead'"
#
# 14: 0.304*"'worry'" + 0.050*"'leave'" + 0.039*"'break'" + 0.029*"'fire'" + 0.027*"'town'" + 0.016*"'moment'" + 0.015*"'return'" + 0.012*"'small'" + 0.012*"'scene'" + 0.011*"'wildfire'" + 0.011*"'thru'" + 0.010*"'rag'" + 0.009*"'frighten'" + 0.009*"'felt'" + 0.006*"'california'"
#
# 15: 0.102*"'wildfire'" + 0.101*"'california'" + 0.063*"'world'" + 0.054*"'northern'" + 0.037*"'fire'" + 0.035*"'dog'" + 0.025*"'believe'" + 0.024*"'literally'" + 0.022*"'force'" + 0.018*"'tree'" + 0.014*"'kind'" + 0.013*"'goat'" + 0.013*"'nobody'" + 0.010*"'warm'" + 0.008*"'cancer'"
#
# 16: 0.000*"'macadoo'" + 0.000*"'referee'" + 0.000*"'ike'" + 0.000*"'emblem'" + 0.000*"'eli'" + 0.000*"'cue'" + 0.000*"'smth'" + 0.000*"'mtf'" + 0.000*"'butidk'" + 0.000*"'reese'" + 0.000*"'emblems'" + 0.000*"'coughlins'" + 0.000*"'tyrant'" + 0.000*"'vein'" + 0.000*"'uninterested'"
#
# 17: 0.126*"'never'" + 0.027*"'mind'" + 0.025*"'fire'" + 0.024*"'fighter'" + 0.018*"'teen'" + 0.018*"'till'" + 0.014*"'nigeria'" + 0.012*"'owner'" + 0.011*"'shop'" + 0.010*"'recent'" + 0.009*"'actual'" + 0.009*"'etc'" + 0.007*"'sexual'" + 0.007*"'coffee'" + 0.006*"'dope'"
#
# 18: 0.162*"'time'" + 0.078*"'fire'" + 0.039*"'season'" + 0.033*"'fight'" + 0.023*"'enough'" + 0.022*"'ppl'" + 0.014*"'rest'" + 0.012*"'stupid'" + 0.012*"'pass'" + 0.012*"'throat'" + 0.011*"'calm'" + 0.010*"'low'" + 0.008*"'butch'" + 0.008*"'release'" + 0.006*"'plane'"
#
# 19: 0.117*"'fire'" + 0.086*"'sonoma'" + 0.068*"'county'" + 0.064*"'napa'" + 0.023*"'men'" + 0.018*"'update'" + 0.018*"'amp'" + 0.017*"'cannabis'" + 0.015*"'injury'" + 0.015*"'mendocino'" + 0.014*"'start'" + 0.013*"'allow'" + 0.011*"'threaten'" + 0.009*"'cal'" + 0.009*"'complex'"
#
# 20: 0.174*"'anxiety'" + 0.069*"'show'" + 0.059*"'fan'" + 0.021*"'heat'" + 0.019*"'wildfire'" + 0.018*"'month'" + 0.016*"'california'" + 0.015*"'insomnia'" + 0.011*"'image'" + 0.009*"'hue'" + 0.008*"'space'" + 0.008*"'date'" + 0.008*"'attempt'" + 0.007*"'search'" + 0.006*"'father'"
#
# 21: 0.109*"'fire'" + 0.082*"'victim'" + 0.071*"'let'" + 0.056*"'someone'" + 0.036*"'talk'" + 0.029*"'california'" + 0.029*"'water'" + 0.014*"'cover'" + 0.010*"'soldier'" + 0.010*"'football'" + 0.010*"'massacre'" + 0.009*"'blood'" + 0.008*"'concert'" + 0.008*"'know'" + 0.008*"'waste'"
#
# 22: 0.071*"'find'" + 0.068*"'wan'" + 0.044*"'forget'" + 0.042*"'face'" + 0.036*"'already'" + 0.034*"'san'" + 0.024*"'francisco'" + 0.023*"'warrior'" + 0.020*"'wonder'" + 0.018*"'yesterday'" + 0.017*"'hair'" + 0.016*"'amazon'" + 0.016*"'winery'" + 0.012*"'fire'" + 0.009*"'bar'"
#
# 23: 0.080*"'kid'" + 0.023*"'quit'" + 0.014*"'brain'" + 0.014*"'fat'" + 0.013*"'draw'" + 0.012*"'strain'" + 0.011*"'terrify'" + 0.011*"'fool'" + 0.007*"'crowd'" + 0.007*"'finale'" + 0.006*"'rumor'" + 0.006*"'stressed'" + 0.006*"'bust'" + 0.006*"'healthcare'" + 0.006*"'thrown'"
#
# 24: 0.190*"'amp'" + 0.053*"'away'" + 0.050*"'fire'" + 0.034*"'safe'" + 0.032*"'stay'" + 0.026*"'hot'" + 0.020*"'lie'" + 0.018*"'sit'" + 0.017*"'stick'" + 0.016*"'fun'" + 0.014*"'halt'" + 0.014*"'cold'" + 0.013*"'glad'" + 0.011*"'fucking'" + 0.010*"'finally'"
#
# 25: 0.041*"'notice'" + 0.037*"'white'" + 0.026*"'footage'" + 0.025*"'begin'" + 0.022*"'kelly'" + 0.014*"'drone'" + 0.014*"'digital'" + 0.010*"'perhaps'" + 0.009*"'senator'" + 0.009*"'reveals'" + 0.007*"'direction'" + 0.007*"'tie'" + 0.007*"'creek'" + 0.006*"'johnson'" + 0.004*"'hack'"
#
# 26: 0.103*"'video'" + 0.029*"'series'" + 0.018*"'channel'" + 0.013*"'bless'" + 0.012*"'drama'" + 0.011*"'jeff'" + 0.011*"'sadden'" + 0.008*"'worker'" + 0.007*"'reunion'" + 0.006*"'accidentally'" + 0.006*"'emotional'" + 0.006*"'dramatic'" + 0.005*"'steve'" + 0.005*"'value'" + 0.004*"'aerial'"
#
# 27: 0.110*"'much'" + 0.083*"'live'" + 0.068*"'tell'" + 0.043*"'fire'" + 0.026*"'reason'" + 0.024*"'stream'" + 0.023*"'mom'" + 0.015*"'conspire'" + 0.012*"'fatigue'" + 0.011*"'local'" + 0.011*"'crash'" + 0.010*"'ass'" + 0.009*"'choice'" + 0.008*"'window'" + 0.007*"'driver'"
#
# 28: 0.148*"'look'" + 0.052*"'blunt'" + 0.025*"'situation'" + 0.025*"'stuff'" + 0.023*"'young'" + 0.021*"'star'" + 0.021*"'staff'" + 0.018*"'smoking'" + 0.014*"'pair'" + 0.012*"'wire'" + 0.008*"'housing'" + 0.008*"'campaign'" + 0.008*"'course'" + 0.007*"'sing'" + 0.007*"'coaching'"
#
# 29: 0.116*"'start'" + 0.070*"'big'" + 0.050*"'tonight'" + 0.032*"'farmer'" + 0.026*"'twitter'" + 0.021*"'medium'" + 0.019*"'social'" + 0.018*"'pain'" + 0.018*"'side'" + 0.016*"'mine'" + 0.009*"'mountain'" + 0.008*"'fire'" + 0.007*"'worse'" + 0.007*"'attention'" + 0.007*"'butt'"
#
# 30: 0.056*"'boy'" + 0.035*"'truck'" + 0.028*"'drill'" + 0.020*"'build'" + 0.018*"'bear'" + 0.012*"'scout'" + 0.011*"'casual'" + 0.007*"'minor'" + 0.007*"'prone'" + 0.005*"'load'" + 0.004*"'etobicoke'" + 0.004*"'parade'" + 0.004*"'boulevard'" + 0.004*"'thin'" + 0.004*"'apology'"
#
# 31: 0.069*"'air'" + 0.032*"'session'" + 0.027*"'check'" + 0.025*"'problem'" + 0.021*"'quality'" + 0.020*"'isolation'" + 0.019*"'poor'" + 0.016*"'cracker'" + 0.016*"'suffocate'" + 0.016*"'arm'" + 0.015*"'zombie'" + 0.014*"'action'" + 0.011*"'clearly'" + 0.010*"'desire'" + 0.010*"'chance'"
#
# 32: 0.100*"'sleep'" + 0.089*"'fire'" + 0.058*"'night'" + 0.058*"'cause'" + 0.052*"'last'" + 0.032*"'area'" + 0.029*"'bay'" + 0.028*"'run'" + 0.025*"'attack'" + 0.025*"'smoke'" + 0.022*"'napa'" + 0.020*"'north'" + 0.019*"'toxic'" + 0.015*"'valley'" + 0.014*"'morning'"
#
# 33: 0.228*"'terrible'" + 0.126*"'fire'" + 0.036*"'keep'" + 0.035*"'family'" + 0.029*"'as'" + 0.029*"'team'" + 0.028*"'first'" + 0.026*"'please'" + 0.025*"'loss'" + 0.025*"'week'" + 0.020*"'listen'" + 0.013*"'stress'" + 0.013*"'eat'" + 0.011*"'disaster'" + 0.009*"'word'"
#
# 34: 0.152*"'take'" + 0.050*"'job'" + 0.039*"'death'" + 0.035*"'name'" + 0.033*"'care'" + 0.029*"'like'" + 0.026*"'wild'" + 0.026*"'due'" + 0.020*"'expect'" + 0.020*"'rebuild'" + 0.015*"'fire'" + 0.007*"'program'" + 0.007*"'nap'" + 0.006*"'buddy'" + 0.005*"'general'"
#
# 35: 0.111*"'home'" + 0.103*"'fire'" + 0.078*"'lose'" + 0.050*"'many'" + 0.036*"'head'" + 0.020*"'point'" + 0.017*"'pumpkin'" + 0.015*"'hey'" + 0.015*"'roll'" + 0.011*"'hill'" + 0.010*"'sad'" + 0.009*"'fix'" + 0.008*"'serious'" + 0.008*"'brush'" + 0.008*"'member'"
#
# 36: 0.110*"'catch'" + 0.071*"'remember'" + 0.043*"'tension'" + 0.034*"'soon'" + 0.027*"'black'" + 0.021*"'breathe'" + 0.020*"'almost'" + 0.018*"'cat'" + 0.014*"'truly'" + 0.013*"'response'" + 0.011*"'ruin'" + 0.010*"'pathetic'" + 0.009*"'haha'" + 0.009*"'dragon'" + 0.006*"'fire'"
#
# 37: 0.155*"'bad'" + 0.074*"'country'" + 0.072*"'wine'" + 0.030*"'panic'" + 0.023*"'jump'" + 0.019*"'mother'" + 0.012*"'california'" + 0.012*"'form'" + 0.006*"'nature'" + 0.006*"'floor'" + 0.006*"'fire'" + 0.005*"'awake'" + 0.004*"'spectator'" + 0.004*"'firestorm'" + 0.003*"'dan'"
#
# 38: 0.407*"'want'" + 0.050*"'also'" + 0.050*"'story'" + 0.020*"'fire'" + 0.019*"'insurance'" + 0.018*"'full'" + 0.017*"'sound'" + 0.011*"'benefit'" + 0.010*"'arrest'" + 0.009*"'bowl'" + 0.008*"'follow'" + 0.006*"'total'" + 0.006*"'property'" + 0.005*"'important'" + 0.004*"'advice'"
#
# 39: 0.114*"'fire'" + 0.103*"'need'" + 0.060*"'help'" + 0.053*"'life'" + 0.041*"'call'" + 0.033*"'great'" + 0.028*"'nothing'" + 0.026*"'something'" + 0.022*"'movie'" + 0.016*"'top'" + 0.013*"'half'" + 0.012*"'hire'" + 0.011*"'get'" + 0.010*"'send'" + 0.010*"'buy'"
#
# 40: 0.161*"'see'" + 0.087*"'play'" + 0.070*"'today'" + 0.058*"'fire'" + 0.031*"'ash'" + 0.030*"'city'" + 0.023*"'crew'" + 0.022*"'smoke'" + 0.021*"'wind'" + 0.014*"'fine'" + 0.013*"'wrong'" + 0.010*"'lake'" + 0.010*"'wildfire'" + 0.010*"'strong'" + 0.009*"'pit'"
#
# 41: 0.065*"'hit'" + 0.055*"'hard'" + 0.025*"'cuz'" + 0.023*"'share'" + 0.021*"'recovery'" + 0.021*"'cali'" + 0.014*"'farm'" + 0.011*"'finna'" + 0.011*"'handle'" + 0.011*"'multiple'" + 0.010*"'york'" + 0.008*"'brave'" + 0.007*"'career'" + 0.005*"'demand'" + 0.004*"'hug'"
#
# 42: 0.096*"'use'" + 0.046*"'sign'" + 0.043*"'ask'" + 0.032*"'illegal'" + 0.032*"'cry'" + 0.018*"'bill'" + 0.016*"'immigrant'" + 0.014*"'evacuee'" + 0.012*"'potus'" + 0.010*"'cross'" + 0.008*"'normal'" + 0.008*"'candle'" + 0.007*"'wonderful'" + 0.006*"'teacher'" + 0.006*"'online'"
#
# 43: 0.051*"'yet'" + 0.045*"'bitch'" + 0.044*"'yes'" + 0.032*"'body'" + 0.031*"'sometimes'" + 0.017*"'quite'" + 0.013*"'incredibly'" + 0.011*"'none'" + 0.010*"'bunch'" + 0.010*"'yall'" + 0.008*"'houston'" + 0.006*"'texas'" + 0.006*"'florida'" + 0.006*"'exercise'" + 0.006*"'hookah'"
#
# 44: 0.098*"'man'" + 0.081*"'tired'" + 0.077*"'everyone'" + 0.069*"'hope'" + 0.032*"'service'" + 0.031*"'tense'" + 0.021*"'firework'" + 0.019*"'survivor'" + 0.015*"'smh'" + 0.014*"'warn'" + 0.007*"'totally'" + 0.006*"'relax'" + 0.005*"'corrupt'" + 0.004*"'jus'" + 0.004*"'blah'"
#
# 45: 0.048*"'rise'" + 0.019*"'threat'" + 0.019*"'democrat'" + 0.017*"'press'" + 0.016*"'douse'" + 0.014*"'hospital'" + 0.014*"'norcal'" + 0.012*"'document'" + 0.012*"'pose'" + 0.006*"'conference'" + 0.004*"'tune'" + 0.004*"'founder'" + 0.004*"'jar'" + 0.003*"'user'" + 0.003*"'tattoo'"
#
# 46: 0.099*"'put'" + 0.030*"'risk'" + 0.026*"'learn'" + 0.025*"'interested'" + 0.010*"'email'" + 0.008*"'november'" + 0.006*"'resource'" + 0.006*"'immediate'" + 0.006*"'research'" + 0.005*"'amen'" + 0.004*"'exceed'" + 0.004*"'creative'" + 0.004*"'lesson'" + 0.003*"'generation'" + 0.002*"'reid'"
#
# 47: 0.039*"'film'" + 0.009*"'review'" + 0.005*"'celebrity'" + 0.004*"'wes'" + 0.004*"'bond'" + 0.003*"'square'" + 0.003*"'eric'" + 0.002*"'notification'" + 0.002*"'prince'" + 0.002*"'randy'" + 0.001*"'sage'" + 0.001*"'underrated'" + 0.001*"'snowman'" + 0.001*"'athlete'" + 0.001*"'muhammed'"
#
# 48: 0.082*"'lot'" + 0.047*"'player'" + 0.018*"'level'" + 0.015*"'account'" + 0.011*"'tiny'" + 0.010*"'speech'" + 0.009*"'info'" + 0.009*"'collusion'" + 0.007*"'melancholy'" + 0.007*"'korea'" + 0.006*"'option'" + 0.005*"'theme'" + 0.005*"'fbi'" + 0.005*"'skill'" + 0.004*"'alot'"
#
# 49: 0.238*"'horror'" + 0.026*"'guess'" + 0.021*"'movie'" + 0.017*"'horrible'" + 0.015*"'outside'" + 0.014*"'usa'" + 0.012*"'ban'" + 0.012*"'fly'" + 0.010*"'scream'" + 0.010*"'whilst'" + 0.009*"'fire'" + 0.008*"'loom'" + 0.008*"'barren'" + 0.008*"'snatch'" + 0.008*"'airplane'"
#
# 50: 0.143*"'go'" + 0.088*"'even'" + 0.085*"'feel'" + 0.035*"'heart'" + 0.035*"'sick'" + 0.026*"'disappointment'" + 0.026*"'sad'" + 0.020*"'able'" + 0.019*"'pretty'" + 0.017*"'wish'" + 0.015*"'imagine'" + 0.015*"'portugal'" + 0.009*"'forever'" + 0.009*"'character'" + 0.008*"'college'"
#
# 51: 0.093*"'guy'" + 0.048*"'hell'" + 0.040*"'anyone'" + 0.035*"'else'" + 0.019*"'america'" + 0.017*"'muslim'" + 0.016*"'cook'" + 0.016*"'refuse'" + 0.014*"'earth'" + 0.013*"'dick'" + 0.013*"'weapon'" + 0.009*"'criminal'" + 0.008*"'drunk'" + 0.008*"'cute'" + 0.006*"'reveal'"
#
# 52: 0.108*"'alarm'" + 0.030*"'forest'" + 0.021*"'defense'" + 0.016*"'detector'" + 0.016*"'experience'" + 0.014*"'ink'" + 0.012*"'sweet'" + 0.011*"'battery'" + 0.010*"'fire'" + 0.010*"'dangerous'" + 0.009*"'massive'" + 0.008*"'version'" + 0.007*"'automatic'" + 0.007*"'clown'" + 0.006*"'beep'"
#
# 53: 0.062*"'pls'" + 0.052*"'fuel'" + 0.027*"'impeachment'" + 0.020*"'donate'" + 0.019*"'blaze'" + 0.018*"'burning'" + 0.017*"'professional'" + 0.016*"'foot'" + 0.015*"'street'" + 0.014*"'dear'" + 0.012*"'feed'" + 0.012*"'caught'" + 0.012*"'system'" + 0.011*"'russian'" + 0.011*"'lord'"
#
# 54: 0.199*"'give'" + 0.121*"'house'" + 0.058*"'friend'" + 0.022*"'idea'" + 0.022*"'claim'" + 0.015*"'evacuate'" + 0.011*"'brother'" + 0.010*"'law'" + 0.010*"'charles'" + 0.009*"'sister'" + 0.009*"'peanut'" + 0.009*"'schulz'" + 0.008*"'creator'" + 0.007*"'husband'" + 0.007*"'fire'"
#
# 55: 0.072*"'god'" + 0.056*"'best'" + 0.050*"'thank'" + 0.021*"'visit'" + 0.020*"'especially'" + 0.013*"'sale'" + 0.011*"'term'" + 0.010*"'chris'" + 0.009*"'judge'" + 0.007*"'king'" + 0.006*"'chicken'" + 0.006*"'fair'" + 0.005*"'containment'" + 0.005*"'genuinely'" + 0.005*"'innocent'"
#
# 56: 0.062*"'damage'" + 0.055*"'act'" + 0.047*"'save'" + 0.026*"'london'" + 0.016*"'pack'" + 0.015*"'racist'" + 0.013*"'archive'" + 0.011*"'bird'" + 0.010*"'badly'" + 0.010*"'joe'" + 0.010*"'shirt'" + 0.007*"'replace'" + 0.007*"'jack'" + 0.007*"'baseball'" + 0.004*"'girlfriend'"
#
# 57: 0.122*"'sure'" + 0.069*"'everything'" + 0.028*"'power'" + 0.018*"'station'" + 0.017*"'shoot'" + 0.014*"'cure'" + 0.012*"'ghost'" + 0.008*"'underground'" + 0.008*"'til'" + 0.007*"'urgently'" + 0.006*"'exhaust'" + 0.006*"'kindle'" + 0.005*"'wet'" + 0.005*"'disturb'" + 0.005*"'suggest'"
#
# 58: 0.061*"'damn'" + 0.055*"'change'" + 0.037*"'health'" + 0.032*"'probably'" + 0.018*"'cleanup'" + 0.015*"'joint'" + 0.015*"'ring'" + 0.015*"'public'" + 0.011*"'climate'" + 0.010*"'redwood'" + 0.009*"'score'" + 0.008*"'manage'" + 0.006*"'prove'" + 0.005*"'bandanas'" + 0.005*"'freedom'"
#
# 59: 0.000*"'ridge'" + 0.000*"'destroy'" + 0.000*"'inn'" + 0.000*"'winery'" + 0.000*"'local'" + 0.000*"'bar'" + 0.000*"'landmark'" + 0.000*"'paradise'" + 0.000*"'fountaingrove'" + 0.000*"'fire'" + 0.000*"'wine'" + 0.000*"'latte'" + 0.000*"'emblems'" + 0.000*"'tofu'" + 0.000*"'ike'"
#
# 60: 0.054*"'throw'" + 0.042*"'free'" + 0.033*"'instead'" + 0.026*"'nice'" + 0.024*"'entire'" + 0.016*"'offer'" + 0.015*"'fuckin'" + 0.014*"'view'" + 0.012*"'avoid'" + 0.011*"'club'" + 0.011*"'proud'" + 0.011*"'green'" + 0.010*"'rohingya'" + 0.010*"'welcome'" + 0.009*"'hoe'"
#
# 61: 0.089*"'light'" + 0.042*"'song'" + 0.040*"'blow'" + 0.037*"'win'" + 0.033*"'screen'" + 0.033*"'wow'" + 0.027*"'pick'" + 0.015*"'trade'" + 0.011*"'everywhere'" + 0.010*"'hopefully'" + 0.008*"'spirit'" + 0.008*"'coordinator'" + 0.005*"'stone'" + 0.004*"'bts'" + 0.004*"'nasty'"
#
# 62: 0.152*"'think'" + 0.061*"'mueller'" + 0.052*"'end'" + 0.035*"'mean'" + 0.023*"'red'" + 0.016*"'future'" + 0.013*"'excuse'" + 0.011*"'mention'" + 0.010*"'hide'" + 0.010*"'danger'" + 0.010*"'anyway'" + 0.009*"'main'" + 0.008*"'track'" + 0.007*"'abt'" + 0.006*"'interest'"
#
# 63: 0.120*"'happen'" + 0.053*"'delay'" + 0.039*"'whole'" + 0.037*"'car'" + 0.019*"'hurricane'" + 0.017*"'urgently'" + 0.016*"'flood'" + 0.015*"'border'" + 0.014*"'cut'" + 0.012*"'ima'" + 0.010*"'thats'" + 0.010*"'capture'" + 0.008*"'hella'" + 0.008*"'pool'" + 0.008*"'busy'"
#
# 64: 0.068*"'open'" + 0.031*"'enjoy'" + 0.031*"'far'" + 0.022*"'animal'" + 0.021*"'gunman'" + 0.019*"'leader'" + 0.013*"'rescue'" + 0.011*"'reach'" + 0.011*"'rave'" + 0.010*"'mostly'" + 0.009*"'remain'" + 0.009*"'shower'" + 0.008*"'noise'" + 0.007*"'shelter'" + 0.005*"'taint'"
#
# 65: 0.220*"'firefighter'" + 0.040*"'weaken'" + 0.031*"'battle'" + 0.012*"'hotel'" + 0.008*"'ida'" + 0.007*"'weedy'" + 0.007*"'contract'" + 0.005*"'strength'" + 0.002*"'hwy'" + 0.002*"'disappoint'" + 0.002*"'jessica'" + 0.002*"'compete'" + 0.002*"'delicious'" + 0.002*"'cornwall'" + 0.002*"'bakery'"
#
# 66: 0.082*"'smell'" + 0.074*"'real'" + 0.023*"'restless'" + 0.021*"'assembly'" + 0.020*"'okay'" + 0.016*"'garbage'" + 0.013*"'kick'" + 0.013*"'comment'" + 0.010*"'inspire'" + 0.010*"'caller'" + 0.009*"'hungry'" + 0.007*"'beer'" + 0.007*"'dodger'" + 0.006*"'mac'" + 0.005*"'language'"
#
# 67: 0.052*"'community'" + 0.008*"'industrial'" + 0.007*"'spring'" + 0.007*"'wreck'" + 0.005*"'teach'" + 0.005*"'waive'" + 0.005*"'bleve'" + 0.005*"'foundation'" + 0.004*"'overall'" + 0.003*"'compromise'" + 0.003*"'thomas'" + 0.003*"'fuller'" + 0.003*"'shopping'" + 0.003*"'cfa'" + 0.002*"'veggie'"
#
# 68: 0.107*"'die'" + 0.099*"'year'" + 0.077*"'try'" + 0.062*"'stop'" + 0.036*"'fire'" + 0.027*"'shot'" + 0.024*"'together'" + 0.023*"'couple'" + 0.018*"'tag'" + 0.013*"'bloody'" + 0.012*"'jesus'" + 0.011*"'pray'" + 0.007*"'rid'" + 0.006*"'self'" + 0.006*"'congress'"
#
# 69: 0.048*"'eye'" + 0.042*"'american'" + 0.030*"'spread'" + 0.024*"'record'" + 0.021*"'cost'" + 0.018*"'list'" + 0.012*"'rapid'" + 0.009*"'canyon'" + 0.008*"'promise'" + 0.007*"'hall'" + 0.007*"'indian'" + 0.005*"'trailer'" + 0.005*"'popular'" + 0.005*"'purchase'" + 0.004*"'ratepayer'"
#
# 70: 0.052*"'mirror'" + 0.042*"'support'" + 0.028*"'cop'" + 0.027*"'suck'" + 0.021*"'app'" + 0.017*"'focus'" + 0.015*"'charge'" + 0.011*"'neighbor'" + 0.011*"'heavy'" + 0.011*"'offensive'" + 0.010*"'ill'" + 0.010*"'dumb'" + 0.009*"'perform'" + 0.008*"'yea'" + 0.007*"'former'"
#
# 71: 0.128*"'shit'" + 0.059*"'fear'" + 0.058*"'post'" + 0.016*"'drug'" + 0.015*"'storm'" + 0.014*"'lil'" + 0.012*"'idk'" + 0.009*"'bruh'" + 0.008*"'swear'" + 0.008*"'worth'" + 0.007*"'rap'" + 0.007*"'extinguisher'" + 0.006*"'gang'" + 0.006*"'forgot'" + 0.006*"'moron'"
#
# 72: 0.173*"'people'" + 0.063*"'kill'" + 0.050*"'miss'" + 0.032*"'person'" + 0.026*"'drop'" + 0.025*"'fire'" + 0.024*"'report'" + 0.024*"'anymore'" + 0.013*"'voice'" + 0.010*"'wildfire'" + 0.008*"'california'" + 0.008*"'alien'" + 0.007*"'forward'" + 0.006*"'fit'" + 0.006*"'consume'"
#
# 73: 0.176*"'watch'" + 0.049*"'flame'" + 0.044*"'depression'" + 0.016*"'fully'" + 0.013*"'race'" + 0.012*"'friendly'" + 0.010*"'condition'" + 0.009*"'private'" + 0.005*"'binge'" + 0.005*"'period'" + 0.004*"'detail'" + 0.004*"'netflix'" + 0.004*"'haunt'" + 0.004*"'india'" + 0.003*"'miami'"
#
# 74: 0.126*"'come'" + 0.060*"'halloween'" + 0.037*"'fire'" + 0.035*"'line'" + 0.027*"'costume'" + 0.024*"'hold'" + 0.020*"'lawmaker'" + 0.017*"'speaker'" + 0.016*"'office'" + 0.015*"'empty'" + 0.015*"'party'" + 0.013*"'exchange'" + 0.012*"'gas'" + 0.011*"'arcade'" + 0.010*"'later'"
#
# 75: 0.102*"'love'" + 0.058*"'emblem'" + 0.039*"'actually'" + 0.027*"'super'" + 0.019*"'joke'" + 0.018*"'trash'" + 0.013*"'wear'" + 0.013*"'decision'" + 0.010*"'lady'" + 0.009*"'solitude'" + 0.009*"'box'" + 0.009*"'field'" + 0.009*"'wont'" + 0.007*"'ship'" + 0.007*"'disagree'"
#
# 76: 0.119*"'fuck'" + 0.051*"'scary'" + 0.039*"'hate'" + 0.025*"'book'" + 0.024*"'write'" + 0.021*"'toll'" + 0.021*"'class'" + 0.020*"'weekend'" + 0.020*"'fire'" + 0.017*"'gun'" + 0.012*"'past'" + 0.011*"'shock'" + 0.010*"'california'" + 0.009*"'cancel'" + 0.008*"'giant'"
#
# 77: 0.065*"'little'" + 0.065*"'always'" + 0.036*"'child'" + 0.033*"'dream'" + 0.028*"'fact'" + 0.023*"'minute'" + 0.022*"'grow'" + 0.022*"'one'" + 0.021*"'ago'" + 0.016*"'straight'" + 0.013*"'pas'" + 0.011*"'tear'" + 0.008*"'pop'" + 0.006*"'negativity'" + 0.006*"'decade'"
#
# 78: 0.066*"'drink'" + 0.045*"'bed'" + 0.031*"'bit'" + 0.029*"'pant'" + 0.028*"'deal'" + 0.017*"'absolutely'" + 0.014*"'loneliness'" + 0.013*"'age'" + 0.013*"'russia'" + 0.012*"'fail'" + 0.012*"'gruden'" + 0.010*"'short'" + 0.010*"'million'" + 0.010*"'murder'" + 0.008*"'anyways'"
#
# 79: 0.000*"'california'" + 0.000*"'fatality'" + 0.000*"'number'" + 0.000*"'people'" + 0.000*"'official'" + 0.000*"'total'" + 0.000*"'bring'" + 0.000*"'fire'" + 0.000*"'calif'" + 0.000*"'sonoma'" + 0.000*"'wildfire'" + 0.000*"'dead'" + 0.000*"'emblems'" + 0.000*"'eli'" + 0.000*"'emblem'"
#
# 80: 0.066*"'move'" + 0.046*"'lmao'" + 0.036*"'jason'" + 0.024*"'fast'" + 0.024*"'picture'" + 0.012*"'extremely'" + 0.006*"'science'" + 0.004*"'curse'" + 0.004*"'metro'" + 0.004*"'glow'" + 0.004*"'furious'" + 0.003*"'wrestling'" + 0.003*"'cookie'" + 0.003*"'refrain'" + 0.002*"'outcome'"
#
# 81: 0.128*"'trump'" + 0.036*"'match'" + 0.018*"'folk'" + 0.016*"'spain'" + 0.015*"'spend'" + 0.012*"'shin'" + 0.011*"'kitchen'" + 0.010*"'likely'" + 0.008*"'opinion'" + 0.008*"'monday'" + 0.008*"'sell'" + 0.008*"'respect'" + 0.007*"'administration'" + 0.007*"'anti'" + 0.006*"'bridge'"
#
# 82: 0.044*"'wtf'" + 0.022*"'lit'" + 0.022*"'seriously'" + 0.016*"'number'" + 0.014*"'bout'" + 0.011*"'afraid'" + 0.005*"'msm'" + 0.005*"'ignites'" + 0.005*"'dat'" + 0.005*"'dis'" + 0.004*"'factory'" + 0.004*"'voter'" + 0.004*"'gore'" + 0.004*"'injured'" + 0.004*"'rush'"
#
# 83: 0.027*"'episode'" + 0.021*"'group'" + 0.015*"'completely'" + 0.008*"'elite'" + 0.007*"'restaurant'" + 0.006*"'daddy'" + 0.006*"'agent'" + 0.006*"'meme'" + 0.005*"'accuse'" + 0.005*"'log'" + 0.005*"'imo'" + 0.005*"'resort'" + 0.005*"'status'" + 0.004*"'drank'" + 0.003*"'goddamn'"
#
# 84: 0.055*"'next'" + 0.027*"'plan'" + 0.025*"'clean'" + 0.022*"'case'" + 0.021*"'pull'" + 0.020*"'tryna'" + 0.018*"'single'" + 0.015*"'dance'" + 0.011*"'government'" + 0.009*"'traffic'" + 0.009*"'legal'" + 0.008*"'deeply'" + 0.007*"'investigator'" + 0.007*"'nearly'" + 0.006*"'personal'"
#
# 85: 0.000*"'macadoo'" + 0.000*"'referee'" + 0.000*"'ike'" + 0.000*"'emblem'" + 0.000*"'eli'" + 0.000*"'cue'" + 0.000*"'smth'" + 0.000*"'mtf'" + 0.000*"'butidk'" + 0.000*"'reese'" + 0.000*"'emblems'" + 0.000*"'coughlins'" + 0.000*"'tyrant'" + 0.000*"'vein'" + 0.000*"'uninterested'"
#
# 86: 0.058*"'do'" + 0.044*"'walk'" + 0.034*"'hurt'" + 0.023*"'road'" + 0.020*"'scar'" + 0.020*"'favorite'" + 0.014*"'clear'" + 0.012*"'market'" + 0.010*"'summer'" + 0.008*"'design'" + 0.007*"'stock'" + 0.007*"'unit'" + 0.007*"'site'" + 0.006*"'stage'" + 0.006*"'deputy'"
#
# 87: 0.056*"'yeah'" + 0.027*"'commit'" + 0.014*"'surprise'" + 0.013*"'dems'" + 0.012*"'crater'" + 0.010*"'iran'" + 0.008*"'crisis'" + 0.008*"'asshole'" + 0.007*"'sober'" + 0.007*"'excellent'" + 0.006*"'mobile'" + 0.005*"'ems'" + 0.004*"'aka'" + 0.004*"'injustice'" + 0.003*"'journey'"

# %%
# Calculate and summarize the total percentage for each topic
for i, topic in enumerate(topics):
    words = topic.split(" + ")
    total_percentage = sum(float(w.split("*")[0]) for w in words)
    print(f"Topic {i}: Total Percentage = {total_percentage:.2%}")
# Out:
# Topic 0: Total Percentage = 56.60%
# Topic 1: Total Percentage = 67.50%
# Topic 2: Total Percentage = 56.70%
# Topic 3: Total Percentage = 75.10%
# Topic 4: Total Percentage = 60.40%
# Topic 5: Total Percentage = 45.00%
# Topic 6: Total Percentage = 48.00%
# Topic 7: Total Percentage = 34.70%
# Topic 8: Total Percentage = 32.90%
# Topic 9: Total Percentage = 46.50%
# Topic 10: Total Percentage = 48.50%
# Topic 11: Total Percentage = 30.20%
# Topic 12: Total Percentage = 58.10%
# Topic 13: Total Percentage = 55.80%
# Topic 14: Total Percentage = 56.00%
# Topic 15: Total Percentage = 53.90%
# Topic 16: Total Percentage = 0.00%
# Topic 17: Total Percentage = 32.30%
# Topic 18: Total Percentage = 45.00%
# Topic 19: Total Percentage = 49.70%
# Topic 20: Total Percentage = 44.80%
# Topic 21: Total Percentage = 48.90%
# Topic 22: Total Percentage = 45.00%
# Topic 23: Total Percentage = 22.20%
# Topic 24: Total Percentage = 51.80%
# Topic 25: Total Percentage = 23.80%
# Topic 26: Total Percentage = 24.40%
# Topic 27: Total Percentage = 46.00%
# Topic 28: Total Percentage = 39.70%
# Topic 29: Total Percentage = 42.40%
# Topic 30: Total Percentage = 21.90%
# Topic 31: Total Percentage = 32.10%
# Topic 32: Total Percentage = 58.60%
# Topic 33: Total Percentage = 65.30%
# Topic 34: Total Percentage = 47.00%
# Topic 35: Total Percentage = 49.90%
# Topic 36: Total Percentage = 41.60%
# Topic 37: Total Percentage = 43.10%
# Topic 38: Total Percentage = 64.00%
# Topic 39: Total Percentage = 55.20%
# Topic 40: Total Percentage = 56.90%
# Topic 41: Total Percentage = 29.10%
# Topic 42: Total Percentage = 35.40%
# Topic 43: Total Percentage = 29.60%
# Topic 44: Total Percentage = 48.30%
# Topic 45: Total Percentage = 19.50%
# Topic 46: Total Percentage = 23.80%
# Topic 47: Total Percentage = 7.80%
# Topic 48: Total Percentage = 24.00%
# Topic 49: Total Percentage = 41.60%
# Topic 50: Total Percentage = 55.00%
# Topic 51: Total Percentage = 35.50%
# Topic 52: Total Percentage = 28.50%
# Topic 53: Total Percentage = 31.80%
# Topic 54: Total Percentage = 51.70%
# Topic 55: Total Percentage = 29.60%
# Topic 56: Total Percentage = 30.00%
# Topic 57: Total Percentage = 33.00%
# Topic 58: Total Percentage = 30.20%
# Topic 59: Total Percentage = 0.00%
# Topic 60: Total Percentage = 29.80%
# Topic 61: Total Percentage = 36.60%
# Topic 62: Total Percentage = 42.30%
# Topic 63: Total Percentage = 38.60%
# Topic 64: Total Percentage = 27.50%
# Topic 65: Total Percentage = 34.40%
# Topic 66: Total Percentage = 31.60%
# Topic 67: Total Percentage = 11.50%
# Topic 68: Total Percentage = 52.80%
# Topic 69: Total Percentage = 24.50%
# Topic 70: Total Percentage = 27.90%
# Topic 71: Total Percentage = 35.90%
# Topic 72: Total Percentage = 47.50%
# Topic 73: Total Percentage = 35.80%
# Topic 74: Total Percentage = 43.80%
# Topic 75: Total Percentage = 34.90%
# Topic 76: Total Percentage = 40.70%
# Topic 77: Total Percentage = 37.50%
# Topic 78: Total Percentage = 31.80%
# Topic 79: Total Percentage = 0.00%
# Topic 80: Total Percentage = 24.10%
# Topic 81: Total Percentage = 29.80%
# Topic 82: Total Percentage = 16.90%
# Topic 83: Total Percentage = 12.80%
# Topic 84: Total Percentage = 26.00%
# Topic 85: Total Percentage = 0.00%
# Topic 86: Total Percentage = 27.60%
# Topic 87: Total Percentage = 18.40%

# %% [markdown]
# # Topic Definition
#
# ### Topic 0: Fire-related Anger and California Wildfires
#
# The prominent keywords such as "fire," "angry," and "say" indicate a focus on anger or frustration related to fires. The mention of "California" and "smoke" suggests a connection to wildfires in that region. Other keywords like "high," "wildfire," and "deadly" further reinforce the fire-related context. Additional keywords like "long," "close," and "school" may suggest specific situations or locations associated with the topic. However, without further context, it's challenging to determine their exact significance.
#
# ### Topic 1: Smoking and its Effects
#
# Based on the provided keywords, the prominent theme of this topic appears to be related to smoking, specifically "smoke," "weed," and "cigarette." Additional keywords such as "day," "bore," "depression," and "fall" might suggest a connection to personal experiences or emotions associated with smoking.
#
# ### Topic 20: Anxiety and Television Show/Fandom
#
# The most prominent keyword is "anxiety," indicating a focus on anxiety-related discussions. Additionally, words like "show" and "fan" suggest a connection to television shows and fandoms. The presence of terms like "insomnia" and "wildfire" might imply specific contexts or themes within the broader topic. However, without further information or context, it is difficult to determine the exact nature of these connections. Therefore, the topic label "Anxiety and Television Show/Fandom" captures the main themes represented by the keywords provided.
#
# ### Topic 31: Air Quality and Concerns
#
# The keywords like "'air'", "'problem'", "'quality'", "'isolation'", and "'poor'" suggest a discussion or mention of issues related to air quality. Additionally, terms like "'suffocate'", "'cracker'", and "'zombie'" imply potential dangers or negative effects associated with the topic. The inclusion of words such as "'session'", "'check'", and "'clearly'" suggests some sort of evaluation or examination of the air quality situation. Overall, these keywords indicate a focus on the quality of air and potential problems or concerns related to it.
#
# ### Topic 44: Emotional Exhaustion and Hope
#
# The prominent keywords such as "'man'", "'tired'", "'everyone'", and "'hope'" indicate a sense of weariness and emotional fatigue. Additionally, words like "'service'", "'tense'", and "'firework'" suggest a potential connection to events or situations that may contribute to this exhaustion. The presence of "'hope'" indicates a glimmer of optimism or a desire for positive change. Considering these elements, the topic can be described as "Emotional Exhaustion and Hope."
#
#
# ### Topic 56: Damage Control and Acts of Saving
#
# The prominent keywords in the list include "damage," "act," and "save," which indicate a focus on mitigating or addressing damage and taking action to save or protect something or someone. Other related keywords like "London," "racist," "archive," and "bird" suggest specific contexts or aspects within this broader theme.
#
# ### Topic 73: Watching Flames and Depression
#
# The most prominent keyword is "'watch'," indicating a focus on observing or monitoring something. The presence of "'flame'" suggests a specific object of observation related to fire or light. Additionally, the keyword "'depression'" indicates that the topic involves discussions or concerns related to mental health. The other keywords, such as "'fully'", "'race'", "'friendly'", "'condition'", "'private'", "'binge'", "'period'", "'detail'", "'Netflix'", "'haunt'", "'India'", and "'Miami'", provide additional context but are not as prominent in the topic.
#
# ### Topic 76: Strong Negative Emotions and Disturbing Experiences
#
# he presence of words like "'fuck'," "'scary'," "'hate'," and "'shock'" indicates strong negative emotions. Additionally, words like "'fire'," "'gun'," and "'california'" suggest potentially distressing or alarming experiences. The keywords "'book'" and "'write'" might indicate a connection to literature or writing, but given their relatively low weights in the list, they don't appear to be central to the topic. Overall, this topic seems to revolve around expressing intense negative emotions and discussing unsettling experiences.
#
# ### Topic 81: Trump
#
# The most prominent keyword in the list is "'Trump," which indicates a focus on or mention of former U.S. President Donald Trump. The word "'match" suggests a potential discussion or context involving matches, which could refer to sports matches, matches as in lighting a fire, or even metaphorical matches. Other keywords like "'folk," "'spain," "'shin," and "'kitchen" provide additional context but do not significantly alter the primary focus on Trump and matches.
